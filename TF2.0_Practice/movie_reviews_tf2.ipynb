# %% [markdown]
# <a href="https://colab.research.google.com/github/SitaramRyali/SDCND_Tensorflow/blob/master/TF2.0_Practice/movie_reviews_tf2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import the tensorflow libraries

# %%
# %tensorflow_version 2.x
import tensorflow as tf
# Out:
# TensorFlow 2.x selected.

# %%
from tensorflow import keras
import numpy as np

# %%
#load the imdb dataset from keras
data = keras.datasets.imdb

# %%
#split the data into training and testing data set
(train_data,train_labels),(test_data,test_labels)=data.load_data(num_words = 10000)
# Out:
# ...
# 17465344/17464789 [==============================] - 0s 0us/step

# %%
print(train_data[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
#create a dictionary of words with their indexes
word_index = data.get_word_index()
# Out:
# ...
# 1646592/1641221 [==============================] - 0s 0us/step

# %%
#(word_index)

# %%
word_index = {k:(v+3) for k,v in word_index.items()}

# %%
word_index['<PAD>'] = 0
word_index["<START>"] =1
word_index["<UNK>"] = 2
word_index["<UNUSED"] = 3

# %%
reverse_word_index  =   dict([(value,key) for (key,value) in word_index.items()])

# %%
train_data = keras.preprocessing.sequence.pad_sequences(train_data,value=word_index['<PAD>'],padding="post",maxlen=250)
test_data = keras.preprocessing.sequence.pad_sequences(test_data,value=word_index['<PAD>'],padding="post",maxlen=250)

# %%
def decode_review (text):
  return " ".join([reverse_word_index.get(i,"?") for i in text])

# %%
print(test_data[10])
print(decode_review(test_data[10]))
# Out:
# [   1 1581   34 7908 5082   23    6 1374 1120    7  107  349    2 1496
#    11 5116   18  397 3767    7    4  107   84 6763   56   68  456 1402
#     2   39    4 1374    9   35  204    5   55 4412  212  193   23    4
#   326   45    6 1109    8 1738    2   15   29  199 1040    5 2684   11
#    14 1403  212 1528   10   10 2160    2    9    4  452   37    2    4
#   598  425    5   45 4394  138   59  214  467    4 2391    7 1738    2
#    19   41 2455 3028    5 6866 1489   90  180   18  101 1403    2 1514
#  5257    9    4  564  871  322   47 2586   27  274  326    5    9  150
#   112    2   17    6   87  162 2133   60 3256   23    4 7999  123    8
#    11    2   29  144   30 2961 1346    2  214    4  326    7    2 1496
#     8 3767  533    7  134    2 6229   10   10    7  265  285    5  233
#    70  593   54  564 4124    2 1625   27 1546    2   19    2 1008   18
#    89    4  114 3209    5   45 1139   32    4   96  143 3760  958    7
# ...

# %%
print(len(test_data[0]),len(test_data[10]))
# Out:
# 250 250

# %% [markdown]
# ### Create the model

# %%
model = keras.Sequential()
model.add(keras.layers.Embedding(10000,16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16,activation="relu"))
model.add(keras.layers.Dense(1,activation="sigmoid"))

# %%
#as shown below we can view the model summary directly
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding (Embedding)        (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# ...
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
x_val = train_data[:10000]
x_train = train_data[10000:]

y_val = train_labels[:10000]
y_train = train_labels[10000:]

# %%
#fit the model now
fitmodel = model.fit(x_train,y_train,epochs = 40, batch_size=512,validation_data=(x_val,y_val),verbose=1)
# Out:
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/40
# 15000/15000 [==============================] - 1s 40us/sample - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.4382 - val_accuracy: 0.9251
# Epoch 2/40
# 15000/15000 [==============================] - 1s 40us/sample - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.4395 - val_accuracy: 0.9250
# Epoch 3/40
# 15000/15000 [==============================] - 1s 40us/sample - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.4404 - val_accuracy: 0.9246
# Epoch 4/40
# 15000/15000 [==============================] - 1s 40us/sample - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.4439 - val_accuracy: 0.9244
# Epoch 5/40
# 15000/15000 [==============================] - 1s 41us/sample - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.4453 - val_accuracy: 0.9239
# Epoch 6/40
# 15000/15000 [==============================] - 1s 40us/sample - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.4520 - val_accuracy: 0.9240
# Epoch 7/40
# ...

# %%
result = model.evaluate(test_data,test_labels)
# Out:
# 25000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %%
print(result)
# Out:
# [1.1155102216684818, 0.84072]

# %% [markdown]
# ### Now lets predict the reviews

# %%
test_review = test_data[4251]
predict = model.predict([test_review])
print("Review: ")
print(decode_review(test_review))
print("Prediction: "+str(predict[0]))
print("Actual: "+str(test_labels[4251]))
print(result)
# Out:
# Review:
# ...
